# %% [markdown]
# # **Data Collection Notebook - Benign and Malignant classification of Skin Lesions**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and prepare it for further processes.
#
# ## Inputs
#
# * https://www.kaggle.com/datasets/bryanqtnguyen/benign-and-malignant-skin-lesion-dataset/data
# * Kaggle JSON file - the authentication token.
#
# ## Outputs
#
# * Generate Dataset:
#     * input/
#         └── Benign_Malignant_Dataset/ (Image files)
#
# * Final Output:
#   * input/
#     * test
#       * benign
#       * malignant
#     * train
#       * benign
#       * malignant
#     * validation
#       * benign
#       * malignant
#
# ## Benign and Malignant Skin Lesion Dataset
#
# This is a dataset that combines images from ISIC 2020 and ISIC 2019. The dataset comprises approximately 4500 images split up between the train, validation, and test sets. This was made for training a CNN with a diverse dataset while staying relatively small for quick and easy feedback.
#
# This dataset splits the images into two classes: benign and malignant.
#
# BCN_20000 Dataset: (c) Department of Dermatology, Hospital Clínic de Barcelona
#
# HAM10000 Dataset: (c) by ViDIR Group, Department of Dermatology, Medical University of Vienna; https://doi.org/10.1038/sdata.2018.161
#
# MSK Dataset: (c) Anonymous; https://arxiv.org/abs/1710.05006; https://arxiv.org/abs/1902.03368
#
# International Skin Imaging Collaboration. SIIM-ISIC 2020 Challenge Dataset. International Skin Imaging Collaboration https://doi.org/10.34970/2020-ds01 (2020).
#
# Creative Commons Attribution-Non Commercial 4.0 International License.
#
# The dataset was generated by the International Skin Imaging Collaboration (ISIC) and images are from the following sources: Hospital Clínic de Barcelona, Medical University of Vienna, Memorial Sloan Kettering Cancer Center, Melanoma Institute Australia, The University of Queensland, and the University of Athens Medical School.

# %% [markdown]
# ---

# %% [markdown]
# # Import packages

# %%
# %pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting streamlit==0.85.0 (from -r ../requirements.txt (line 2))
#   Downloading streamlit-0.85.0-py2.py3-none-any.whl.metadata (1.1 kB)
# Collecting altair<5 (from -r ../requirements.txt (line 3))
#   Downloading altair-4.2.2-py3-none-any.whl.metadata (13 kB)
# Collecting astor (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading astor-0.8.1-py2.py3-none-any.whl.metadata (4.2 kB)
# Collecting attrs (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Collecting base58 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading base58-2.1.1-py3-none-any.whl.metadata (3.1 kB)
# Collecting blinker (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached blinker-1.7.0-py3-none-any.whl.metadata (1.9 kB)
# Collecting cachetools>=4.0 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached cachetools-5.3.3-py3-none-any.whl.metadata (5.3 kB)
# Collecting click<8.0,>=7.0 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading click-7.1.2-py2.py3-none-any.whl.metadata (2.9 kB)
# Collecting numpy (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl.metadata (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 4.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (24.0)
# Collecting pandas>=0.21.0 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading pandas-2.2.1-cp39-cp39-macosx_11_0_arm64.whl.metadata (19 kB)
# Collecting pillow>=6.2.0 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading pillow-10.3.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (9.2 kB)
# Collecting protobuf!=3.11,>=3.6.0 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading protobuf-5.26.1-cp37-abi3-macosx_10_9_universal2.whl.metadata (592 bytes)
# Collecting pyarrow (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading pyarrow-15.0.2-cp39-cp39-macosx_11_0_arm64.whl.metadata (3.0 kB)
# Collecting pydeck>=0.1.dev5 (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached pydeck-0.8.1b0-py2.py3-none-any.whl.metadata (3.9 kB)
# Requirement already satisfied: python-dateutil in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.31.0)
# Collecting toml (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached toml-0.10.2-py2.py3-none-any.whl.metadata (7.1 kB)
# Requirement already satisfied: tornado>=5.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (6.4)
# Collecting tzlocal (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading tzlocal-5.2-py3-none-any.whl.metadata (7.8 kB)
# Collecting validators (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading validators-0.26.0-py3-none-any.whl.metadata (3.6 kB)
# Collecting gitpython (from streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Downloading GitPython-3.1.43-py3-none-any.whl.metadata (13 kB)
# Collecting entrypoints (from altair<5->-r ../requirements.txt (line 3))
#   Downloading entrypoints-0.4-py3-none-any.whl.metadata (2.6 kB)
# Collecting jinja2 (from altair<5->-r ../requirements.txt (line 3))
#   Using cached Jinja2-3.1.3-py3-none-any.whl.metadata (3.3 kB)
# Collecting jsonschema>=3.0 (from altair<5->-r ../requirements.txt (line 3))
#   Using cached jsonschema-4.21.1-py3-none-any.whl.metadata (7.8 kB)
# Collecting toolz (from altair<5->-r ../requirements.txt (line 3))
#   Using cached toolz-0.12.1-py3-none-any.whl.metadata (5.1 kB)
# Collecting jsonschema-specifications>=2023.03.6 (from jsonschema>=3.0->altair<5->-r ../requirements.txt (line 3))
#   Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl.metadata (3.0 kB)
# Collecting referencing>=0.28.4 (from jsonschema>=3.0->altair<5->-r ../requirements.txt (line 3))
#   Downloading referencing-0.34.0-py3-none-any.whl.metadata (2.8 kB)
# Collecting rpds-py>=0.7.1 (from jsonschema>=3.0->altair<5->-r ../requirements.txt (line 3))
#   Downloading rpds_py-0.18.0-cp39-cp39-macosx_11_0_arm64.whl.metadata (4.1 kB)
# Collecting pytz>=2020.1 (from pandas>=0.21.0->streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached pytz-2024.1-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas>=0.21.0->streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached tzdata-2024.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting MarkupSafe>=2.0 (from jinja2->altair<5->-r ../requirements.txt (line 3))
#   Downloading MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_universal2.whl.metadata (3.0 kB)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil->streamlit==0.85.0->-r ../requirements.txt (line 2)) (1.15.0)
# Collecting gitdb<5,>=4.0.1 (from gitpython->streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached gitdb-4.0.11-py3-none-any.whl.metadata (1.2 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (2024.2.2)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->gitpython->streamlit==0.85.0->-r ../requirements.txt (line 2))
#   Using cached smmap-5.0.1-py3-none-any.whl.metadata (4.3 kB)
# Downloading streamlit-0.85.0-py2.py3-none-any.whl (7.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.9/7.9 MB 2.5 MB/s eta 0:00:0000:0100:01m
# Downloading altair-4.2.2-py3-none-any.whl (813 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 813.6/813.6 kB 6.8 MB/s eta 0:00:0000:0100:01
# Using cached cachetools-5.3.3-py3-none-any.whl (9.3 kB)
# Downloading click-7.1.2-py2.py3-none-any.whl (82 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.8/82.8 kB 5.4 MB/s eta 0:00:00
# Using cached jsonschema-4.21.1-py3-none-any.whl (85 kB)
# Using cached attrs-23.2.0-py3-none-any.whl (60 kB)
# Downloading pandas-2.2.1-cp39-cp39-macosx_11_0_arm64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 7.3 MB/s eta 0:00:0000:0100:01
# Downloading numpy-1.26.4-cp39-cp39-macosx_11_0_arm64.whl (14.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.0/14.0 MB 9.7 MB/s eta 0:00:0000:01m00:01
# Downloading pillow-10.3.0-cp39-cp39-macosx_11_0_arm64.whl (3.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 5.2 MB/s eta 0:00:0000:0100:01
# Downloading protobuf-5.26.1-cp37-abi3-macosx_10_9_universal2.whl (404 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 404.0/404.0 kB 3.5 MB/s eta 0:00:00a 0:00:01
# Using cached pydeck-0.8.1b0-py2.py3-none-any.whl (4.8 MB)
# Using cached Jinja2-3.1.3-py3-none-any.whl (133 kB)
# Downloading astor-0.8.1-py2.py3-none-any.whl (27 kB)
# Downloading base58-2.1.1-py3-none-any.whl (5.6 kB)
# Using cached blinker-1.7.0-py3-none-any.whl (13 kB)
# Downloading entrypoints-0.4-py3-none-any.whl (5.3 kB)
# Downloading GitPython-3.1.43-py3-none-any.whl (207 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.3/207.3 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Downloading pyarrow-15.0.2-cp39-cp39-macosx_11_0_arm64.whl (24.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 5.0 MB/s eta 0:00:0000:0100:01
# Using cached toml-0.10.2-py2.py3-none-any.whl (16 kB)
# Using cached toolz-0.12.1-py3-none-any.whl (56 kB)
# Downloading tzlocal-5.2-py3-none-any.whl (17 kB)
# Downloading validators-0.26.0-py3-none-any.whl (28 kB)
# Using cached gitdb-4.0.11-py3-none-any.whl (62 kB)
# Using cached jsonschema_specifications-2023.12.1-py3-none-any.whl (18 kB)
# Downloading MarkupSafe-2.1.5-cp39-cp39-macosx_10_9_universal2.whl (18 kB)
# Using cached pytz-2024.1-py2.py3-none-any.whl (505 kB)
# Downloading referencing-0.34.0-py3-none-any.whl (26 kB)
# Downloading rpds_py-0.18.0-cp39-cp39-macosx_11_0_arm64.whl (330 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 331.0/331.0 kB 11.2 MB/s eta 0:00:00
# Using cached tzdata-2024.1-py2.py3-none-any.whl (345 kB)
# Using cached smmap-5.0.1-py3-none-any.whl (24 kB)
# Installing collected packages: pytz, validators, tzlocal, tzdata, toolz, toml, smmap, rpds-py, protobuf, pillow, numpy, MarkupSafe, entrypoints, click, cachetools, blinker, base58, attrs, astor, referencing, pyarrow, pandas, jinja2, gitdb, pydeck, jsonschema-specifications, gitpython, jsonschema, altair, streamlit
# Successfully installed MarkupSafe-2.1.5 altair-4.2.2 astor-0.8.1 attrs-23.2.0 base58-2.1.1 blinker-1.7.0 cachetools-5.3.3 click-7.1.2 entrypoints-0.4 gitdb-4.0.11 gitpython-3.1.43 jinja2-3.1.3 jsonschema-4.21.1 jsonschema-specifications-2023.12.1 numpy-1.26.4 pandas-2.2.1 pillow-10.3.0 protobuf-5.26.1 pyarrow-15.0.2 pydeck-0.8.1b0 pytz-2024.1 referencing-0.34.0 rpds-py-0.18.0 smmap-5.0.1 streamlit-0.85.0 toml-0.10.2 toolz-0.12.1 tzdata-2024.1 tzlocal-5.2 validators-0.26.0
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Change working directory

# %% [markdown]
# * Because the Jupyter notebooks are in a subfolder, we need to change the directory for the code's execution

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/carolina/Documents/CodeInstitute/breast-cancer-prediction/jupyter_notebooks'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/carolina/Documents/CodeInstitute/breast-cancer-prediction'

# %% [markdown]
# ## Setup Kaggle

# %% [markdown]
# Install Kaggle

# %%
# %pip install kaggle==1.5.12
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting kaggle==1.5.12
#   Downloading kaggle-1.5.12.tar.gz (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.0/59.0 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: six>=1.10 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from kaggle==1.5.12) (1.15.0)
# Requirement already satisfied: certifi in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2024.2.2)
# Requirement already satisfied: python-dateutil in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2.31.0)
# Collecting tqdm (from kaggle==1.5.12)
#   Downloading tqdm-4.66.2-py3-none-any.whl.metadata (57 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 6.9 MB/s eta 0:00:00
# Collecting python-slugify (from kaggle==1.5.12)
#   Downloading python_slugify-8.0.4-py2.py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: urllib3 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2.2.0)
# Collecting text-unidecode>=1.3 (from python-slugify->kaggle==1.5.12)
#   Downloading text_unidecode-1.3-py2.py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->kaggle==1.5.12) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->kaggle==1.5.12) (3.6)
# Downloading python_slugify-8.0.4-py2.py3-none-any.whl (10 kB)
# Downloading tqdm-4.66.2-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 8.6 MB/s eta 0:00:00
# Downloading text_unidecode-1.3-py2.py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.2/78.2 kB 11.4 MB/s eta 0:00:00
# Building wheels for collected packages: kaggle
#   Building wheel for kaggle (setup.py) ... done
#   Created wheel for kaggle: filename=kaggle-1.5.12-py3-none-any.whl size=73051 sha256=49cf92b2d687ebee917dd9bda6a8efb6d4c6e3e197072ff97d12f018b4b29087
#   Stored in directory: /Users/carolina/Library/Caches/pip/wheels/ac/b2/c3/fa4706d469b5879105991d1c8be9a3c2ef329ba9fe2ce5085e
# Successfully built kaggle
# Installing collected packages: text-unidecode, tqdm, python-slugify, kaggle
# Successfully installed kaggle-1.5.12 python-slugify-8.0.4 text-unidecode-1.3 tqdm-4.66.2
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Setup Kaggle details

# %%
# Kaggle json file and directory setup
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %%
KaggleDatasetPath = "bryanqtnguyen/benign-and-malignant-skin-lesion-dataset/data"
DestinationFolder = "input/"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# /Users/carolina/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Downloading benign-and-malignant-skin-lesion-dataset.zip to input
# 100%|███████████████████████████████████████▉| 835M/836M [00:38<00:00, 27.2MB/s]
# 100%|████████████████████████████████████████| 836M/836M [00:38<00:00, 23.0MB/s]

# %% [markdown]
# Unzip the dowloaded file and delete the zip file

# %%
import zipfile
with zipfile.ZipFile(DestinationFolder + '/benign-and-malignant-skin-lesion-dataset.zip' , 'r') as zip_ref:
    zip_ref.extractall(DestinationFolder)

os.remove(DestinationFolder + 'benign-and-malignant-skin-lesion-dataset.zip')

# %% [markdown]
# ---

# %% [markdown]
# # Section 2

# %% [markdown]
# Section 2 content

# %% [markdown]
# ---

# %% [markdown]
# NOTE

# %% [markdown]
# * You may add as many sections as you want, as long as it supports your project workflow.
# * All notebook's cells should be run top-down (you can't create a dynamic wherein a given point you need to go back to a previous cell to execute some task, like go back to a previous cell and refresh a variable content)

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# * In case you don't need to push files to Repo, you may replace this section with "Conclusions and Next Steps" and state your conclusions and next steps.

# %%
import os
try:
  # create here your folder
  # os.makedirs(name='')
except Exception as e:
  print(e)
