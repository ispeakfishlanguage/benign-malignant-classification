# %% [markdown]
# # **Data Collection Notebook - Benign and Malignant classification of Skin Lesions**

# %% [markdown]
# ## Objectives
#
# * Fetch data from Kaggle and prepare it for further processes.
#
# ## Inputs
#
# * https://www.kaggle.com/datasets/bryanqtnguyen/benign-and-malignant-skin-lesion-dataset/data
# * Kaggle JSON file - the authentication token.
#
# ## Outputs
#
# * Generate Dataset:
#     * input/
#       * Benign_Malignant_Dataset/MainData
#
# * Final Output:
#   * input/Benign_Malignant_Dataset/MainData/
#     * test
#       * benign
#       * malignant
#     * train
#       * benign
#       * malignant
#     * validation
#       * benign
#       * malignant
#
# ## Benign and Malignant Skin Lesion Dataset
#
# This is a dataset that combines images from ISIC 2020 and ISIC 2019. The dataset comprises approximately 4500 images split up between the train, validation, and test sets. This was made for training a CNN with a diverse dataset while staying relatively small for quick and easy feedback.
#
# This dataset splits the images into two classes: benign and malignant.
#
# BCN_20000 Dataset: (c) Department of Dermatology, Hospital Clínic de Barcelona
#
# HAM10000 Dataset: (c) by ViDIR Group, Department of Dermatology, Medical University of Vienna; https://doi.org/10.1038/sdata.2018.161
#
# MSK Dataset: (c) Anonymous; https://arxiv.org/abs/1710.05006; https://arxiv.org/abs/1902.03368
#
# International Skin Imaging Collaboration. SIIM-ISIC 2020 Challenge Dataset. International Skin Imaging Collaboration https://doi.org/10.34970/2020-ds01 (2020).
#
# Creative Commons Attribution-Non Commercial 4.0 International License.
#
# The dataset was generated by the International Skin Imaging Collaboration (ISIC) and images are from the following sources: Hospital Clínic de Barcelona, Medical University of Vienna, Memorial Sloan Kettering Cancer Center, Melanoma Institute Australia, The University of Queensland, and the University of Athens Medical School.

# %% [markdown]
# ---

# %% [markdown]
# # Import packages

# %%
# %pip install -r ../requirements.txt
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: streamlit==0.85.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 2)) (0.85.0)
# Requirement already satisfied: altair<5 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from -r ../requirements.txt (line 3)) (4.2.2)
# Requirement already satisfied: astor in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (0.8.1)
# Requirement already satisfied: attrs in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (23.2.0)
# Requirement already satisfied: base58 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.1.1)
# Requirement already satisfied: blinker in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (1.7.0)
# Requirement already satisfied: cachetools>=4.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (5.3.3)
# Requirement already satisfied: click<8.0,>=7.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (7.1.2)
# Requirement already satisfied: numpy in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (1.26.4)
# Requirement already satisfied: packaging in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (24.0)
# Requirement already satisfied: pandas>=0.21.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.2.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (10.3.0)
# Requirement already satisfied: protobuf!=3.11,>=3.6.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (5.26.1)
# Requirement already satisfied: pyarrow in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (15.0.2)
# Requirement already satisfied: pydeck>=0.1.dev5 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (0.8.1b0)
# Requirement already satisfied: python-dateutil in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.31.0)
# Requirement already satisfied: toml in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (0.10.2)
# Requirement already satisfied: tornado>=5.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (6.4)
# Requirement already satisfied: tzlocal in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (5.2)
# Requirement already satisfied: validators in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (0.26.0)
# Requirement already satisfied: gitpython in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from streamlit==0.85.0->-r ../requirements.txt (line 2)) (3.1.43)
# Requirement already satisfied: entrypoints in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from altair<5->-r ../requirements.txt (line 3)) (0.4)
# Requirement already satisfied: jinja2 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from altair<5->-r ../requirements.txt (line 3)) (3.1.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from altair<5->-r ../requirements.txt (line 3)) (4.21.1)
# Requirement already satisfied: toolz in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from altair<5->-r ../requirements.txt (line 3)) (0.12.1)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<5->-r ../requirements.txt (line 3)) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<5->-r ../requirements.txt (line 3)) (0.34.0)
# Requirement already satisfied: rpds-py>=0.7.1 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from jsonschema>=3.0->altair<5->-r ../requirements.txt (line 3)) (0.18.0)
# Requirement already satisfied: pytz>=2020.1 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from pandas>=0.21.0->streamlit==0.85.0->-r ../requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from pandas>=0.21.0->streamlit==0.85.0->-r ../requirements.txt (line 2)) (2024.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from jinja2->altair<5->-r ../requirements.txt (line 3)) (2.1.5)
# Requirement already satisfied: six>=1.5 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from python-dateutil->streamlit==0.85.0->-r ../requirements.txt (line 2)) (1.15.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from gitpython->streamlit==0.85.0->-r ../requirements.txt (line 2)) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->streamlit==0.85.0->-r ../requirements.txt (line 2)) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from gitdb<5,>=4.0.1->gitpython->streamlit==0.85.0->-r ../requirements.txt (line 2)) (5.0.1)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Change working directory

# %% [markdown]
# * Because the Jupyter notebooks are in a subfolder, we need to change the directory for the code's execution

# %% [markdown]
# We need to change the working directory from its current folder to its parent folder
# * We access the current directory with os.getcwd()

# %%
import os
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/carolina/Documents/CodeInstitute'

# %% [markdown]
# We want to make the parent of the current directory the new current directory
# * os.path.dirname() gets the parent directory
# * os.chir() defines the new current directory

# %%
os.chdir(os.path.dirname(current_dir))
print("You set a new current directory")
# Out:
# You set a new current directory

# %% [markdown]
# Confirm the new current directory

# %%
current_dir = os.getcwd()
current_dir
# Out:
# '/Users/carolina/Documents/CodeInstitute'

# %% [markdown]
# ## Setup Kaggle

# %% [markdown]
# Install Kaggle

# %%
# %pip install kaggle==1.5.12
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: kaggle==1.5.12 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (1.5.12)
# Requirement already satisfied: six>=1.10 in /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.9/lib/python3.9/site-packages (from kaggle==1.5.12) (1.15.0)
# Requirement already satisfied: certifi in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2024.2.2)
# Requirement already satisfied: python-dateutil in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2.9.0.post0)
# Requirement already satisfied: requests in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2.31.0)
# Requirement already satisfied: tqdm in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (4.66.2)
# Requirement already satisfied: python-slugify in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (8.0.4)
# Requirement already satisfied: urllib3 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from kaggle==1.5.12) (2.2.0)
# Requirement already satisfied: text-unidecode>=1.3 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from python-slugify->kaggle==1.5.12) (1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->kaggle==1.5.12) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/carolina/Library/Python/3.9/lib/python/site-packages (from requests->kaggle==1.5.12) (3.6)
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Setup Kaggle details

# %%
# Kaggle json file and directory setup
os.environ['KAGGLE_CONFIG_DIR'] = os.getcwd()
! chmod 600 kaggle.json

# %%
KaggleDatasetPath = "bryanqtnguyen/benign-and-malignant-skin-lesion-dataset/data"
DestinationFolder = "input/"   
! kaggle datasets download -d {KaggleDatasetPath} -p {DestinationFolder}
# Out:
# /Users/carolina/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
# Downloading benign-and-malignant-skin-lesion-dataset.zip to input
# 100%|███████████████████████████████████████▉| 834M/836M [00:30<00:00, 30.4MB/s]
# 100%|████████████████████████████████████████| 836M/836M [00:30<00:00, 28.6MB/s]

# %% [markdown]
# Unzip the dowloaded file and delete the zip file

# %%
import zipfile
with zipfile.ZipFile(DestinationFolder + '/benign-and-malignant-skin-lesion-dataset.zip' , 'r') as zip_ref:
    zip_ref.extractall(DestinationFolder)

os.remove(DestinationFolder + 'benign-and-malignant-skin-lesion-dataset.zip')

# %% [markdown]
# The dataset comes pre-sorted into Test, Train and Validation folders containing only image files.

# %% [markdown]
# ---

# %% [markdown]
# # Push files to Repo

# %% [markdown]
# ---

# %% [markdown]
# * git add .

# %%
# !git add .

# %% [markdown]
# * git commit

# %%
# !git commit -m "Added Kaggle dataset and extracted it"
# Out:
# [main fdfbb0d] Added Kaggle dataset and extracted it
#  4 files changed, 99 insertions(+), 156 deletions(-)
#  create mode 100644 .DS_Store
#  create mode 100644 input/.DS_Store
#  create mode 100644 input/Benign_Malignant_DataSet/.DS_Store

# %% [markdown]
# * git push

# %%
# !git push
# Out:
# Everything up-to-date
